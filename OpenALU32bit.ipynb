# %% [markdown]
# <a href="https://colab.research.google.com/github/vjkr/OpenALU32bit/blob/main/OpenALU32bit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Practising Pull Request and Merging PR using simple ALU code on Python
# #### This notebook is from the following Github Repo https://github.com/vjkr/OpenALU32bit.git
# Few simple instructions
# - Do not use special characters or spaces in filenames.
# - The steps to Create a Pull Request is explained in detail in this video https://www.youtube.com/watch?v=8MWMvoZqt0E
# - For any queries you can put a message on my LinkedIn post https://www.linkedin.com/feed/update/urn:li:activity:7214517848755384320/
# - Or mail me at ec.vijaykumar@bldeacet.ac.in
#
# So what happens in GitHub?
# https://www.linkedin.com/pulse/git-github-demystified-guide-open-source-contribution-nishan-baral-i4ndc/
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Prerequisites
# Step 1 : Fork https://github.com/vjkr/OpenALU32bit.git to your GitHub account as https://github.com/yourname/OpenALU32bit.git on GitHub website
#
# Step 2 : Clone 'your' repo here by replacing link in below code

# %%
#Replace the URL here with your URL of your copy of repo
# !git clone https://github.com/vjkr/OpenALU32bit.git
# Out:
# fatal: destination path 'OpenALU32bit' already exists and is not an empty directory.

# %% [markdown]
# ### Our working directory structure here in Colab

# %%
# %cd /content/OpenALU32bit
import sys
sys.path.clear()
sys.path.append('/content/OpenALU32bit')
print(sys.path)
# !pwd
# !ls
# Out:
# /content/OpenALU32bit
# ['/content/OpenALU32bit']
# /content/OpenALU32bit
# adder.py   LICENSE	NAND.py  OpenALU32bit	     __pycache__  XNOR.py
# AND.py	   main.py	NOR.py	 OpenALU32bit.ipynb  README.md	  XOR.py
# divide.py  multiply.py	NOT.py	 OR.py		     subtract.py

# %% [markdown]
# ## What is an ALU?
# https://www.researchgate.net/figure/Block-diagram-of-an-ALU_fig1_251093842
# ![image.png](data:image/png;base64,...)

# %%
A= input("Enter the value of first number A:")
B= input("Enter the value of first number B:")

import adder
adder.add(6,4)
import subtract
subtract.subtract(6,4)
import multiply
multiply.run()
import divide
divide.run()
import AND
AND.run()
import OR
OR.run()
import NAND
NAND.run()
import NOR
NOR.run()
import NOT
NOT.run()
import XOR
XOR.run()
import XNOR
XNOR.run()
# Out:
# Enter the value of first number A:9
# Enter the value of first number B:9
# The result of subtracting 4 from 6 is 10
# The result of subtracting 4 from 6 is 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-647174676c51> in <cell line: 9>()
#       7 subtract.subtract(6,4)
#       8 import multiply
# ----> 9 multiply.run()
#      10 import divide
#      11 divide.run()
#
# AttributeError: module 'multiply' has no attribute 'run'
